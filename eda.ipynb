# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'airline_passenger_satisfaction.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
#    ...  On-board Service  Seat Comfort  Leg Room Service  Cleanliness  \
# 0  ...                 3             5                 2            5
# 1  ...                 5             4                 5            5
# 2  ...                 3             5                 3            5
# 3  ...                 5             5                 5            4
# 4  ...                 3             4                 4            5
#
#    Food and Drink  In-flight Service  In-flight Wifi Service  \
# 0               5                  5                       3
# 1               3                  5                       2
# 2               5                  3                       4
# 3               4                  5                       2
# 4               4                  3                       3
#
#    In-flight Entertainment  Baggage Handling             Satisfaction
# 0                        5                 5  Neutral or Dissatisfied
# 1                        5                 5                Satisfied
# 2                        3                 3                Satisfied
# 3                        5                 5                Satisfied
# 4                        3                 3                Satisfied
#
# [5 rows x 24 columns]

# %%
print("Shape of the dataset:", df.shape)
# Out:
# Shape of the dataset: (129880, 24)

# %%
print("\nSummary of the dataset:")
print(df.describe(include='all'))
# Out:
# Summary of the dataset:
#                    ID  Gender            Age Customer Type Type of Travel  \
# count   129880.000000  129880  129880.000000        129880         129880
# unique            NaN       2            NaN             2              2
# top               NaN  Female            NaN     Returning       Business
# freq              NaN   65899            NaN        106100          89693
# mean     64940.500000     NaN      39.427957           NaN            NaN
# std      37493.270818     NaN      15.119360           NaN            NaN
# min          1.000000     NaN       7.000000           NaN            NaN
# 25%      32470.750000     NaN      27.000000           NaN            NaN
# 50%      64940.500000     NaN      40.000000           NaN            NaN
# 75%      97410.250000     NaN      51.000000           NaN            NaN
# max     129880.000000     NaN      85.000000           NaN            NaN
#
#            Class  Flight Distance  Departure Delay  Arrival Delay  \
# count     129880    129880.000000    129880.000000  129487.000000
# unique         3              NaN              NaN            NaN
# top     Business              NaN              NaN            NaN
# freq       62160              NaN              NaN            NaN
# mean         NaN      1190.316392        14.713713      15.091129
# std          NaN       997.452477        38.071126      38.465650
# min          NaN        31.000000         0.000000       0.000000
# 25%          NaN       414.000000         0.000000       0.000000
# 50%          NaN       844.000000         0.000000       0.000000
# 75%          NaN      1744.000000        12.000000      13.000000
# max          NaN      4983.000000      1592.000000    1584.000000
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# count                            129880.000000  ...     129880.000000
# unique                                     NaN  ...               NaN
# top                                        NaN  ...               NaN
# freq                                       NaN  ...               NaN
# mean                                  3.057599  ...          3.383023
# std                                   1.526741  ...          1.287099
# min                                   0.000000  ...          0.000000
# 25%                                   2.000000  ...          2.000000
# 50%                                   3.000000  ...          4.000000
# 75%                                   4.000000  ...          4.000000
# max                                   5.000000  ...          5.000000
#
#          Seat Comfort  Leg Room Service    Cleanliness  Food and Drink  \
# count   129880.000000     129880.000000  129880.000000   129880.000000
# unique            NaN               NaN            NaN             NaN
# top               NaN               NaN            NaN             NaN
# freq              NaN               NaN            NaN             NaN
# mean         3.441361          3.350878       3.286326        3.204774
# std          1.319289          1.316252       1.313682        1.329933
# min          0.000000          0.000000       0.000000        0.000000
# 25%          2.000000          2.000000       2.000000        2.000000
# 50%          4.000000          4.000000       3.000000        3.000000
# 75%          5.000000          4.000000       4.000000        4.000000
# max          5.000000          5.000000       5.000000        5.000000
#
#         In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# count       129880.000000           129880.000000            129880.000000
# unique                NaN                     NaN                      NaN
# top                   NaN                     NaN                      NaN
# freq                  NaN                     NaN                      NaN
# mean             3.642193                2.728696                 3.358077
# std              1.176669                1.329340                 1.334049
# min              0.000000                0.000000                 0.000000
# 25%              3.000000                2.000000                 2.000000
# 50%              4.000000                3.000000                 4.000000
# 75%              5.000000                4.000000                 4.000000
# max              5.000000                5.000000                 5.000000
#
#         Baggage Handling             Satisfaction
# count      129880.000000                   129880
# unique               NaN                        2
# top                  NaN  Neutral or Dissatisfied
# freq                 NaN                    73452
# mean            3.632114                      NaN
# std             1.180025                      NaN
# min             1.000000                      NaN
# 25%             3.000000                      NaN
# 50%             4.000000                      NaN
# 75%             5.000000                      NaN
# max             5.000000                      NaN
#
# [11 rows x 24 columns]

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# In-flight Wifi Service                      0
# In-flight Entertainment                     0
# Baggage Handling                            0
# Satisfaction                                0
# dtype: int64

# %%
df = df.dropna()  # Example: Dropping rows with missing values
print("\nShape after handling missing values:", df.shape)
# Out:
# Shape after handling missing values: (129487, 24)

# %%
print("\nData types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                             int64
# Departure Delay                             int64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience      int64
# Ease of Online Booking                      int64
# Check-in Service                            int64
# Online Boarding                             int64
# Gate Location                               int64
# On-board Service                            int64
# Seat Comfort                                int64
# Leg Room Service                            int64
# Cleanliness                                 int64
# Food and Drink                              int64
# In-flight Service                           int64
# In-flight Wifi Service                      int64
# In-flight Entertainment                     int64
# Baggage Handling                            int64
# Satisfaction                               object
# dtype: object

# %%
print("\nNumber of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print("\nUnivariate Analysis:")
for column in df.select_dtypes(include=[np.number]).columns:
    print(f"\nColumn: {column}")
    print(df[column].describe())
    plt.figure(figsize=(8, 4))
    sns.histplot(df[column], kde=True, bins=20, color='blue')
    plt.title(f"Distribution of {column}")
    plt.show()
# Out:
# Univariate Analysis:
#
# Column: ID
# count    129487.000000
# mean      64958.335169
# std       37489.781165
# min           1.000000
# 25%       32494.500000
# 50%       64972.000000
# 75%       97415.500000
# max      129880.000000
# Name: ID, dtype: float64
# Column: Age
# count    129487.000000
# mean         39.428761
# std          15.117597
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64
# Column: Flight Distance
# count    129487.000000
# mean       1190.210662
# std         997.560954
# min          31.000000
# 25%         414.000000
# 50%         844.000000
# 75%        1744.000000
# max        4983.000000
# Name: Flight Distance, dtype: float64
# Column: Departure Delay
# count    129487.000000
# mean         14.643385
# std          37.932867
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max        1592.000000
# Name: Departure Delay, dtype: float64
# Column: Arrival Delay
# count    129487.000000
# mean         15.091129
# std          38.465650
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay, dtype: float64
# Column: Departure and Arrival Time Convenience
# count    129487.000000
# mean          3.057349
# std           1.526787
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Departure and Arrival Time Convenience, dtype: float64
# Column: Ease of Online Booking
# count    129487.000000
# mean          2.756786
# std           1.401662
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Ease of Online Booking, dtype: float64
# Column: Check-in Service
# count    129487.000000
# mean          3.306239
# std           1.266146
# min           0.000000
# 25%           3.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Check-in Service, dtype: float64
# Column: Online Boarding
# count    129487.000000
# mean          3.252720
# std           1.350651
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Online Boarding, dtype: float64
# Column: Gate Location
# count    129487.000000
# mean          2.976909
# std           1.278506
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Gate Location, dtype: float64
# Column: On-board Service
# count    129487.000000
# mean          3.383204
# std           1.287032
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: On-board Service, dtype: float64
# Column: Seat Comfort
# count    129487.000000
# mean          3.441589
# std           1.319168
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# Name: Seat Comfort, dtype: float64
# Column: Leg Room Service
# count    129487.000000
# mean          3.351078
# std           1.316132
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: Leg Room Service, dtype: float64
# Column: Cleanliness
# count    129487.000000
# mean          3.286222
# std           1.313624
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Cleanliness, dtype: float64
# Column: Food and Drink
# count    129487.000000
# mean          3.204685
# std           1.329905
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Food and Drink, dtype: float64
# Column: In-flight Service
# count    129487.000000
# mean          3.642373
# std           1.176614
# min           0.000000
# 25%           3.000000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# Name: In-flight Service, dtype: float64
# Column: In-flight Wifi Service
# count    129487.000000
# mean          2.728544
# std           1.329235
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: In-flight Wifi Service, dtype: float64
# Column: In-flight Entertainment
# count    129487.000000
# mean          3.358067
# std           1.334149
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: In-flight Entertainment, dtype: float64
# Column: Baggage Handling
# count    129487.000000
# mean          3.631886
# std           1.180082
# min           1.000000
# 25%           3.000000
# 50%           4.000000
# 75%           5.000000
# max           5.000000
# Name: Baggage Handling, dtype: float64

# %%
print("\nBivariate Analysis:")
numerical_columns = df.select_dtypes(include=[np.number]).columns
categorical_columns = df.select_dtypes(include=['object']).columns

for num_col in numerical_columns:
    for cat_col in categorical_columns:
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=df[cat_col], y=df[num_col])
        plt.title(f"{num_col} vs {cat_col}")
        plt.xticks(rotation=45)
        plt.show()
# Out:
# Bivariate Analysis:

# %%
print("\nMultivariate Analysis:")
numerical_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(12, 8))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Multivariate Analysis:

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
df = df.fillna(df.mean())

# %%
scaler = StandardScaler()
numerical_data = df.select_dtypes(include=[np.number])
scaled_data = scaler.fit_transform(numerical_data)

# %%
k = 3
kmeans = KMeans(n_clusters=k, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_data)

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# %%
plt.figure(figsize=(10, 7))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['Cluster'], cmap='viridis', s=50)
plt.title('Clusters Visualized using PCA')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
print("\nCluster Summary:")
print(df.groupby('Cluster').mean())
# Out:
# Cluster Summary:
#                    ID    Gender        Age  Customer Type  Type of Travel  \
# Cluster
# 0        69375.439866  0.490076  43.080157       0.906450        0.044920
# 1        61169.670445  0.457465  40.503246       0.837369        0.478294
# 2        64357.469057  0.541039  33.504093       0.679055        0.419586
#
#             Class  Flight Distance  Departure Delay  Arrival Delay  \
# Cluster
# 0        0.136296      1693.820585        12.558356      12.622925
# 1        0.858726       931.430526        13.242837      13.872957
# 2        0.820208       898.231472        19.042049      19.730681
#
#          Departure and Arrival Time Convenience  ...  On-board Service  \
# Cluster                                          ...
# 0                                      3.041868  ...          4.198538
# 1                                      3.112876  ...          2.763613
# 2                                      3.004939  ...          3.169395
#
#          Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# Cluster
# 0            4.176956          4.135725     3.919448        3.653882
# 1            3.850838          2.711404     3.792878        3.817259
# 2            1.999536          3.201321     1.845421        1.855927
#
#          In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# Cluster
# 0                 4.306182                3.208352                 4.306644
# 1                 3.033558                2.585270                 3.493371
# 2                 3.602980                2.317098                 2.004530
#
#          Baggage Handling  Satisfaction
# Cluster
# 0                4.303636      0.928361
# 1                3.013512      0.191263
# 2                3.594957      0.134578
#
# [3 rows x 24 columns]
